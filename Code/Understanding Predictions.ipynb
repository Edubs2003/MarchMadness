# %%
import pandas as pd

df = pd.read_csv('marchmadness_model24.csv')
# Out:
#       SEED_1       TEAM_1  SEED_2          TEAM_2  Team1W_Prob
# 0        1.0  Connecticut     1.0         Houston        0.360
# 1        1.0  Connecticut     1.0  North Carolina        0.778
# 2        1.0  Connecticut     1.0          Purdue        0.547
# 3        1.0  Connecticut     2.0         Arizona        0.690
# 4        1.0  Connecticut     2.0        Iowa St.        0.611
# ...      ...          ...     ...             ...          ...
# 4551    16.0       Wagner    16.0   Grambling St.        0.418
# 4552    16.0       Wagner    16.0          Howard        0.492
# 4553    16.0       Wagner    16.0        Longwood        0.212
# 4554    16.0       Wagner    16.0     Montana St.        0.388
# 4555    16.0       Wagner    16.0         Stetson        0.345
#
# [4556 rows x 5 columns]

# %%
def get_team1_winning_probability(df, team1, team2):
    """
    Searches for the match between team1 and team2 in the dataframe and prints out the probability
    of team1 winning.
    
    Parameters:
    - df: Pandas DataFrame containing the match data
    - team1: Name of Team 1
    - team2: Name of Team 2
    """
    # Filter the dataframe for the specific match
    match = df[((df['TEAM_1'] == team1) & (df['TEAM_2'] == team2)) | ((df['TEAM_1'] == team2) & (df['TEAM_2'] == team1))]
    
    # Check if the match is found and print the probability
    if not match.empty:
        # Determine if team1 is actually TEAM_1 in the data for the correct probability
        if match.iloc[0]['TEAM_1'] == team1:
            print(f"Probability of {team1} winning against {team2}: {match.iloc[0]['Team1W_Prob']:.3f}")
        else:
            print(f"Probability of {team1} winning against {team2}: {1 - match.iloc[0]['Team1W_Prob']:.3f}")
    else:
        print("Match not found.")

# Example usage:
get_team1_winning_probability(df, "", "Marquette")
# Out:
# Probability of Texas Tech winning against Marquette: 0.332

# %%
def print_all_matchups_for_team1(df, team1):
    """
    Searches for all matches involving team1 and prints out the matchups along with the probability
    of team1 winning each match.
    
    Parameters:
    - df: Pandas DataFrame containing the match data
    - team1: Name of Team 1
    """
    # Filter the dataframe for matches involving team1 either as TEAM_1 or TEAM_2
    matches = df[(df['TEAM_1'] == team1) | (df['TEAM_2'] == team1)]
    
    # Check if there are matches found
    if not matches.empty:
        print(f"Matchups for {team1} and their winning probabilities:")
        for index, row in matches.iterrows():
            # Determine if team1 is TEAM_1 or TEAM_2 in the data
            if row['TEAM_1'] == team1:
                opponent = row['TEAM_2']
                prob = row['Team1W_Prob']
            else:
                opponent = row['TEAM_1']
                prob = 1 - row['Team1W_Prob']
            print(f"{team1} vs {opponent}: {prob:.3f}")
    else:
        print("No matchups found for this team.")

# Example usage
print_all_matchups_for_team1(df, "Arizona")
# Out:
# Matchups for Arizona and their winning probabilities:
# Arizona vs Connecticut: 0.310
# Arizona vs Houston: 0.202
# Arizona vs North Carolina: 0.611
# Arizona vs Purdue: 0.352
# Arizona vs Connecticut: 0.310
# Arizona vs Houston: 0.202
# Arizona vs North Carolina: 0.611
# Arizona vs Purdue: 0.352
# Arizona vs Iowa St.: 0.414
# Arizona vs Marquette: 0.557
# Arizona vs Tennessee: 0.561
# Arizona vs Baylor: 0.632
# Arizona vs Creighton: 0.720
# Arizona vs Illinois: 0.619
# Arizona vs Kentucky: 0.723
# Arizona vs Alabama: 0.626
# Arizona vs Auburn: 0.464
# Arizona vs Duke: 0.628
# Arizona vs Kansas: 0.705
# Arizona vs Gonzaga: 0.656
# Arizona vs Saint Mary's: 0.680
# Arizona vs San Diego St.: 0.735
# Arizona vs Wisconsin: 0.675
# Arizona vs BYU: 0.651
# Arizona vs Clemson: 0.803
# Arizona vs South Carolina: 0.756
# Arizona vs Texas Tech: 0.717
# Arizona vs Dayton: 0.765
# Arizona vs Florida: 0.684
# Arizona vs Texas: 0.704
# Arizona vs Washington St.: 0.781
# Arizona vs Florida Atlantic: 0.776
# Arizona vs Mississippi St.: 0.745
# Arizona vs Nebraska: 0.725
# Arizona vs Utah St.: 0.782
# Arizona vs Michigan St.: 0.695
# Arizona vs Northwestern: 0.734
# Arizona vs TCU: 0.702
# Arizona vs Texas A&M: 0.734
# Arizona vs Boise St.: 0.763
# Arizona vs Colorado: 0.728
# Arizona vs Colorado St.: 0.769
# Arizona vs Drake: 0.785
# Arizona vs Nevada: 0.726
# Arizona vs Virginia: 0.786
# Arizona vs Duquesne: 0.859
# Arizona vs New Mexico: 0.631
# Arizona vs North Carolina St.: 0.811
# Arizona vs Oregon: 0.775
# Arizona vs Grand Canyon: 0.782
# Arizona vs James Madison: 0.767
# Arizona vs McNeese St.: 0.761
# Arizona vs UAB: 0.903
# Arizona vs College of Charleston: 0.867
# Arizona vs Samford: 0.815
# Arizona vs Vermont: 0.908
# Arizona vs Yale: 0.869
# Arizona vs Akron: 0.929
# Arizona vs Colgate: 0.951
# Arizona vs Morehead St.: 0.929
# Arizona vs Oakland: 0.929
# Arizona vs Long Beach St.: 0.960
# Arizona vs Saint Peter's: 0.963
# Arizona vs South Dakota St.: 0.950
# Arizona vs Western Kentucky: 0.938
# Arizona vs Grambling St.: 0.980
# Arizona vs Howard: 0.985
# Arizona vs Longwood: 0.949
# Arizona vs Montana St.: 0.978
# Arizona vs Stetson: 0.973
# Arizona vs Wagner: 0.986
# Arizona vs Iowa St.: 0.414
# Arizona vs Marquette: 0.557
# Arizona vs Tennessee: 0.561
# Arizona vs Baylor: 0.632
# Arizona vs Creighton: 0.720
# Arizona vs Illinois: 0.619
# Arizona vs Kentucky: 0.723
# Arizona vs Alabama: 0.626
# Arizona vs Auburn: 0.464
# Arizona vs Duke: 0.628
# Arizona vs Kansas: 0.705
# Arizona vs Gonzaga: 0.656
# Arizona vs Saint Mary's: 0.680
# Arizona vs San Diego St.: 0.735
# Arizona vs Wisconsin: 0.675
# Arizona vs BYU: 0.651
# Arizona vs Clemson: 0.803
# Arizona vs South Carolina: 0.756
# Arizona vs Texas Tech: 0.717
# Arizona vs Dayton: 0.765
# Arizona vs Florida: 0.684
# Arizona vs Texas: 0.704
# Arizona vs Washington St.: 0.781
# Arizona vs Florida Atlantic: 0.776
# Arizona vs Mississippi St.: 0.745
# Arizona vs Nebraska: 0.725
# Arizona vs Utah St.: 0.782
# Arizona vs Michigan St.: 0.695
# Arizona vs Northwestern: 0.734
# Arizona vs TCU: 0.702
# Arizona vs Texas A&M: 0.734
# Arizona vs Boise St.: 0.763
# Arizona vs Colorado: 0.728
# Arizona vs Colorado St.: 0.769
# Arizona vs Drake: 0.785
# Arizona vs Nevada: 0.726
# Arizona vs Virginia: 0.786
# Arizona vs Duquesne: 0.859
# Arizona vs New Mexico: 0.631
# Arizona vs North Carolina St.: 0.811
# Arizona vs Oregon: 0.775
# Arizona vs Grand Canyon: 0.782
# Arizona vs James Madison: 0.767
# Arizona vs McNeese St.: 0.761
# Arizona vs UAB: 0.903
# Arizona vs College of Charleston: 0.867
# Arizona vs Samford: 0.815
# Arizona vs Vermont: 0.908
# Arizona vs Yale: 0.869
# Arizona vs Akron: 0.929
# Arizona vs Colgate: 0.951
# Arizona vs Morehead St.: 0.929
# Arizona vs Oakland: 0.929
# Arizona vs Long Beach St.: 0.960
# Arizona vs Saint Peter's: 0.963
# Arizona vs South Dakota St.: 0.950
# Arizona vs Western Kentucky: 0.938
# Arizona vs Grambling St.: 0.980
# Arizona vs Howard: 0.985
# Arizona vs Longwood: 0.949
# Arizona vs Montana St.: 0.978
# Arizona vs Stetson: 0.973
# Arizona vs Wagner: 0.986

# %%
def print_upset_predictions(df):
    """
    Searches for and prints out every matchup where team1 is a lower seed than team2 (meaning a higher
    numerical seed value, which indicates a lower rank) but the model predicts that team2 will win
    (Team1W_Prob is less than 0.50).
    """
    # Filter the dataframe for matches where TEAM_1 has a higher seed number than TEAM_2 and
    # Team1W_Prob is less than 0.50
    upset_matches = df[(df['SEED_1'] < df['SEED_2']) & (df['Team1W_Prob'] < 0.55) & (df['Team1W_Prob'] > 0.45)]
    
    # Check if there are any such matches
    if not upset_matches.empty:
        print("Matchups where a lower-seeded TEAM_1 is predicted to lose to a higher-seeded TEAM_2:")
        for index, row in upset_matches.iterrows():
            print(f"Seed {int(row['SEED_1'])} {row['TEAM_1']} vs Seed {int(row['SEED_2'])} {row['TEAM_2']}: TEAM_2 Winning Probability: {1 - row['Team1W_Prob']:.3f}")
    else:
        print("No such matchups found.")

# Call the function to print upset predictions
print_upset_predictions(df)
# Out:
# Matchups where a lower-seeded TEAM_1 is predicted to lose to a higher-seeded TEAM_2:
# Seed 1 North Carolina vs Seed 3 Baylor: TEAM_2 Winning Probability: 0.478
# Seed 1 North Carolina vs Seed 3 Illinois: TEAM_2 Winning Probability: 0.492
# Seed 1 North Carolina vs Seed 4 Alabama: TEAM_2 Winning Probability: 0.484
# Seed 1 North Carolina vs Seed 4 Duke: TEAM_2 Winning Probability: 0.482
# Seed 1 North Carolina vs Seed 5 Gonzaga: TEAM_2 Winning Probability: 0.452
# Seed 1 North Carolina vs Seed 6 BYU: TEAM_2 Winning Probability: 0.457
# Seed 1 North Carolina vs Seed 11 New Mexico: TEAM_2 Winning Probability: 0.479
# Seed 2 Arizona vs Seed 4 Auburn: TEAM_2 Winning Probability: 0.536
# Seed 3 Baylor vs Seed 4 Alabama: TEAM_2 Winning Probability: 0.506
# Seed 3 Baylor vs Seed 4 Duke: TEAM_2 Winning Probability: 0.504
# Seed 3 Baylor vs Seed 5 Gonzaga: TEAM_2 Winning Probability: 0.474
# Seed 3 Baylor vs Seed 5 Wisconsin: TEAM_2 Winning Probability: 0.452
# Seed 3 Baylor vs Seed 6 BYU: TEAM_2 Winning Probability: 0.479
# Seed 3 Baylor vs Seed 11 New Mexico: TEAM_2 Winning Probability: 0.501
# Seed 3 Creighton vs Seed 4 Kansas: TEAM_2 Winning Probability: 0.518
# Seed 3 Creighton vs Seed 5 Saint Mary's: TEAM_2 Winning Probability: 0.548
# Seed 3 Creighton vs Seed 5 San Diego St.: TEAM_2 Winning Probability: 0.481
# Seed 3 Creighton vs Seed 6 South Carolina: TEAM_2 Winning Probability: 0.453
# Seed 3 Creighton vs Seed 6 Texas Tech: TEAM_2 Winning Probability: 0.504
# Seed 3 Creighton vs Seed 7 Florida: TEAM_2 Winning Probability: 0.543
# Seed 3 Creighton vs Seed 7 Texas: TEAM_2 Winning Probability: 0.520
# Seed 3 Creighton vs Seed 8 Mississippi St.: TEAM_2 Winning Probability: 0.468
# Seed 3 Creighton vs Seed 8 Nebraska: TEAM_2 Winning Probability: 0.495
# Seed 3 Creighton vs Seed 9 Michigan St.: TEAM_2 Winning Probability: 0.531
# Seed 3 Creighton vs Seed 9 Northwestern: TEAM_2 Winning Probability: 0.482
# Seed 3 Creighton vs Seed 9 TCU: TEAM_2 Winning Probability: 0.522
# Seed 3 Creighton vs Seed 9 Texas A&M: TEAM_2 Winning Probability: 0.482
# Seed 3 Creighton vs Seed 10 Colorado: TEAM_2 Winning Probability: 0.491
# Seed 3 Creighton vs Seed 10 Nevada: TEAM_2 Winning Probability: 0.492
# Seed 3 Illinois vs Seed 4 Alabama: TEAM_2 Winning Probability: 0.492
# Seed 3 Illinois vs Seed 4 Duke: TEAM_2 Winning Probability: 0.490
# Seed 3 Illinois vs Seed 5 Gonzaga: TEAM_2 Winning Probability: 0.460
# Seed 3 Illinois vs Seed 6 BYU: TEAM_2 Winning Probability: 0.465
# Seed 3 Illinois vs Seed 11 New Mexico: TEAM_2 Winning Probability: 0.488
# Seed 3 Kentucky vs Seed 4 Kansas: TEAM_2 Winning Probability: 0.523
# Seed 3 Kentucky vs Seed 5 San Diego St.: TEAM_2 Winning Probability: 0.485
# Seed 3 Kentucky vs Seed 6 South Carolina: TEAM_2 Winning Probability: 0.457
# Seed 3 Kentucky vs Seed 6 Texas Tech: TEAM_2 Winning Probability: 0.508
# Seed 3 Kentucky vs Seed 7 Florida: TEAM_2 Winning Probability: 0.548
# Seed 3 Kentucky vs Seed 7 Texas: TEAM_2 Winning Probability: 0.524
# Seed 3 Kentucky vs Seed 8 Mississippi St.: TEAM_2 Winning Probability: 0.472
# Seed 3 Kentucky vs Seed 8 Nebraska: TEAM_2 Winning Probability: 0.499
# Seed 3 Kentucky vs Seed 9 Michigan St.: TEAM_2 Winning Probability: 0.535
# Seed 3 Kentucky vs Seed 9 Northwestern: TEAM_2 Winning Probability: 0.486
# Seed 3 Kentucky vs Seed 9 TCU: TEAM_2 Winning Probability: 0.526
# Seed 3 Kentucky vs Seed 9 Texas A&M: TEAM_2 Winning Probability: 0.487
# Seed 3 Kentucky vs Seed 10 Colorado: TEAM_2 Winning Probability: 0.495
# Seed 3 Kentucky vs Seed 10 Nevada: TEAM_2 Winning Probability: 0.497
# Seed 3 Kentucky vs Seed 12 McNeese St.: TEAM_2 Winning Probability: 0.451
# Seed 4 Alabama vs Seed 5 Gonzaga: TEAM_2 Winning Probability: 0.468
# Seed 4 Alabama vs Seed 6 BYU: TEAM_2 Winning Probability: 0.473
# Seed 4 Alabama vs Seed 11 New Mexico: TEAM_2 Winning Probability: 0.495
# Seed 4 Duke vs Seed 5 Gonzaga: TEAM_2 Winning Probability: 0.470
# Seed 4 Duke vs Seed 6 BYU: TEAM_2 Winning Probability: 0.475
# Seed 4 Duke vs Seed 11 New Mexico: TEAM_2 Winning Probability: 0.497
# Seed 4 Kansas vs Seed 5 Saint Mary's: TEAM_2 Winning Probability: 0.529
# Seed 4 Kansas vs Seed 5 San Diego St.: TEAM_2 Winning Probability: 0.463
# Seed 4 Kansas vs Seed 5 Wisconsin: TEAM_2 Winning Probability: 0.535
# Seed 4 Kansas vs Seed 6 Texas Tech: TEAM_2 Winning Probability: 0.486
# Seed 4 Kansas vs Seed 7 Florida: TEAM_2 Winning Probability: 0.525
# Seed 4 Kansas vs Seed 7 Texas: TEAM_2 Winning Probability: 0.502
# Seed 4 Kansas vs Seed 8 Nebraska: TEAM_2 Winning Probability: 0.476
# Seed 4 Kansas vs Seed 9 Michigan St.: TEAM_2 Winning Probability: 0.512
# Seed 4 Kansas vs Seed 9 Northwestern: TEAM_2 Winning Probability: 0.464
# Seed 4 Kansas vs Seed 9 TCU: TEAM_2 Winning Probability: 0.503
# Seed 4 Kansas vs Seed 9 Texas A&M: TEAM_2 Winning Probability: 0.464
# Seed 4 Kansas vs Seed 10 Colorado: TEAM_2 Winning Probability: 0.472
# Seed 4 Kansas vs Seed 10 Nevada: TEAM_2 Winning Probability: 0.474
# Seed 5 Gonzaga vs Seed 6 BYU: TEAM_2 Winning Probability: 0.505
# Seed 5 Gonzaga vs Seed 7 Florida: TEAM_2 Winning Probability: 0.469
# Seed 5 Gonzaga vs Seed 9 Michigan St.: TEAM_2 Winning Probability: 0.456
# Seed 5 Gonzaga vs Seed 11 New Mexico: TEAM_2 Winning Probability: 0.528
# Seed 5 Saint Mary's vs Seed 6 BYU: TEAM_2 Winning Probability: 0.532
# Seed 5 Saint Mary's vs Seed 6 Texas Tech: TEAM_2 Winning Probability: 0.456
# Seed 5 Saint Mary's vs Seed 7 Florida: TEAM_2 Winning Probability: 0.496
# Seed 5 Saint Mary's vs Seed 7 Texas: TEAM_2 Winning Probability: 0.472
# Seed 5 Saint Mary's vs Seed 9 Michigan St.: TEAM_2 Winning Probability: 0.483
# Seed 5 Saint Mary's vs Seed 9 TCU: TEAM_2 Winning Probability: 0.474
# Seed 5 San Diego St. vs Seed 6 South Carolina: TEAM_2 Winning Probability: 0.472
# Seed 5 San Diego St. vs Seed 6 Texas Tech: TEAM_2 Winning Probability: 0.523
# Seed 5 San Diego St. vs Seed 7 Dayton: TEAM_2 Winning Probability: 0.460
# Seed 5 San Diego St. vs Seed 7 Texas: TEAM_2 Winning Probability: 0.539
# Seed 5 San Diego St. vs Seed 8 Mississippi St.: TEAM_2 Winning Probability: 0.487
# Seed 5 San Diego St. vs Seed 8 Nebraska: TEAM_2 Winning Probability: 0.513
# Seed 5 San Diego St. vs Seed 9 Michigan St.: TEAM_2 Winning Probability: 0.549
# Seed 5 San Diego St. vs Seed 9 Northwestern: TEAM_2 Winning Probability: 0.501
# Seed 5 San Diego St. vs Seed 9 TCU: TEAM_2 Winning Probability: 0.541
# Seed 5 San Diego St. vs Seed 9 Texas A&M: TEAM_2 Winning Probability: 0.501
# Seed 5 San Diego St. vs Seed 10 Boise St.: TEAM_2 Winning Probability: 0.463
# Seed 5 San Diego St. vs Seed 10 Colorado: TEAM_2 Winning Probability: 0.509
# Seed 5 San Diego St. vs Seed 10 Colorado St.: TEAM_2 Winning Probability: 0.454
# Seed 5 San Diego St. vs Seed 10 Nevada: TEAM_2 Winning Probability: 0.511
# Seed 5 San Diego St. vs Seed 12 James Madison: TEAM_2 Winning Probability: 0.457
# Seed 5 San Diego St. vs Seed 12 McNeese St.: TEAM_2 Winning Probability: 0.466
# Seed 5 Wisconsin vs Seed 6 BYU: TEAM_2 Winning Probability: 0.527
# Seed 5 Wisconsin vs Seed 6 Texas Tech: TEAM_2 Winning Probability: 0.451
# Seed 5 Wisconsin vs Seed 7 Florida: TEAM_2 Winning Probability: 0.490
# Seed 5 Wisconsin vs Seed 7 Texas: TEAM_2 Winning Probability: 0.467
# Seed 5 Wisconsin vs Seed 9 Michigan St.: TEAM_2 Winning Probability: 0.478
# Seed 5 Wisconsin vs Seed 9 TCU: TEAM_2 Winning Probability: 0.469
# Seed 5 Wisconsin vs Seed 11 New Mexico: TEAM_2 Winning Probability: 0.549
# Seed 6 BYU vs Seed 7 Florida: TEAM_2 Winning Probability: 0.463
# Seed 6 BYU vs Seed 9 Michigan St.: TEAM_2 Winning Probability: 0.451
# Seed 6 BYU vs Seed 11 New Mexico: TEAM_2 Winning Probability: 0.522
# Seed 6 Clemson vs Seed 7 Washington St.: TEAM_2 Winning Probability: 0.533
# Seed 6 Clemson vs Seed 8 Florida Atlantic: TEAM_2 Winning Probability: 0.540
# Seed 6 Clemson vs Seed 8 Utah St.: TEAM_2 Winning Probability: 0.531
# Seed 6 Clemson vs Seed 10 Drake: TEAM_2 Winning Probability: 0.527
# Seed 6 Clemson vs Seed 10 Virginia: TEAM_2 Winning Probability: 0.526
# Seed 6 Clemson vs Seed 11 North Carolina St.: TEAM_2 Winning Probability: 0.488
# Seed 6 Clemson vs Seed 11 Oregon: TEAM_2 Winning Probability: 0.541
# Seed 6 Clemson vs Seed 12 Grand Canyon: TEAM_2 Winning Probability: 0.532
# Seed 6 Clemson vs Seed 13 Samford: TEAM_2 Winning Probability: 0.481
# Seed 6 South Carolina vs Seed 7 Dayton: TEAM_2 Winning Probability: 0.488
# Seed 6 South Carolina vs Seed 7 Washington St.: TEAM_2 Winning Probability: 0.465
# Seed 6 South Carolina vs Seed 8 Florida Atlantic: TEAM_2 Winning Probability: 0.472
# Seed 6 South Carolina vs Seed 8 Mississippi St.: TEAM_2 Winning Probability: 0.515
# Seed 6 South Carolina vs Seed 8 Nebraska: TEAM_2 Winning Probability: 0.541
# Seed 6 South Carolina vs Seed 8 Utah St.: TEAM_2 Winning Probability: 0.464
# Seed 6 South Carolina vs Seed 9 Northwestern: TEAM_2 Winning Probability: 0.529
# Seed 6 South Carolina vs Seed 9 Texas A&M: TEAM_2 Winning Probability: 0.529
# Seed 6 South Carolina vs Seed 10 Boise St.: TEAM_2 Winning Probability: 0.491
# Seed 6 South Carolina vs Seed 10 Colorado: TEAM_2 Winning Probability: 0.537
# Seed 6 South Carolina vs Seed 10 Colorado St.: TEAM_2 Winning Probability: 0.482
# Seed 6 South Carolina vs Seed 10 Drake: TEAM_2 Winning Probability: 0.459
# Seed 6 South Carolina vs Seed 10 Nevada: TEAM_2 Winning Probability: 0.539
# Seed 6 South Carolina vs Seed 10 Virginia: TEAM_2 Winning Probability: 0.458
# Seed 6 South Carolina vs Seed 11 Oregon: TEAM_2 Winning Probability: 0.474
# Seed 6 South Carolina vs Seed 12 Grand Canyon: TEAM_2 Winning Probability: 0.465
# Seed 6 South Carolina vs Seed 12 James Madison: TEAM_2 Winning Probability: 0.485
# Seed 6 South Carolina vs Seed 12 McNeese St.: TEAM_2 Winning Probability: 0.494
# Seed 6 Texas Tech vs Seed 7 Florida: TEAM_2 Winning Probability: 0.539
# Seed 6 Texas Tech vs Seed 7 Texas: TEAM_2 Winning Probability: 0.516
# Seed 6 Texas Tech vs Seed 8 Mississippi St.: TEAM_2 Winning Probability: 0.464
# Seed 6 Texas Tech vs Seed 8 Nebraska: TEAM_2 Winning Probability: 0.490
# Seed 6 Texas Tech vs Seed 9 Michigan St.: TEAM_2 Winning Probability: 0.526
# Seed 6 Texas Tech vs Seed 9 Northwestern: TEAM_2 Winning Probability: 0.478
# Seed 6 Texas Tech vs Seed 9 TCU: TEAM_2 Winning Probability: 0.518
# Seed 6 Texas Tech vs Seed 9 Texas A&M: TEAM_2 Winning Probability: 0.478
# Seed 6 Texas Tech vs Seed 10 Colorado: TEAM_2 Winning Probability: 0.486
# Seed 6 Texas Tech vs Seed 10 Nevada: TEAM_2 Winning Probability: 0.488
# Seed 7 Dayton vs Seed 8 Florida Atlantic: TEAM_2 Winning Probability: 0.484
# Seed 7 Dayton vs Seed 8 Mississippi St.: TEAM_2 Winning Probability: 0.527
# Seed 7 Dayton vs Seed 8 Utah St.: TEAM_2 Winning Probability: 0.475
# Seed 7 Dayton vs Seed 9 Northwestern: TEAM_2 Winning Probability: 0.541
# Seed 7 Dayton vs Seed 9 Texas A&M: TEAM_2 Winning Probability: 0.541
# Seed 7 Dayton vs Seed 10 Boise St.: TEAM_2 Winning Probability: 0.503
# Seed 7 Dayton vs Seed 10 Colorado: TEAM_2 Winning Probability: 0.549
# Seed 7 Dayton vs Seed 10 Colorado St.: TEAM_2 Winning Probability: 0.494
# Seed 7 Dayton vs Seed 10 Drake: TEAM_2 Winning Probability: 0.471
# Seed 7 Dayton vs Seed 10 Virginia: TEAM_2 Winning Probability: 0.470
# Seed 7 Dayton vs Seed 11 Oregon: TEAM_2 Winning Probability: 0.486
# Seed 7 Dayton vs Seed 12 Grand Canyon: TEAM_2 Winning Probability: 0.477
# Seed 7 Dayton vs Seed 12 James Madison: TEAM_2 Winning Probability: 0.497
# Seed 7 Dayton vs Seed 12 McNeese St.: TEAM_2 Winning Probability: 0.506
# Seed 7 Florida vs Seed 8 Nebraska: TEAM_2 Winning Probability: 0.451
# Seed 7 Florida vs Seed 9 Michigan St.: TEAM_2 Winning Probability: 0.487
# Seed 7 Florida vs Seed 9 TCU: TEAM_2 Winning Probability: 0.478
# Seed 7 Texas vs Seed 8 Nebraska: TEAM_2 Winning Probability: 0.474
# Seed 7 Texas vs Seed 9 Michigan St.: TEAM_2 Winning Probability: 0.510
# Seed 7 Texas vs Seed 9 Northwestern: TEAM_2 Winning Probability: 0.462
# Seed 7 Texas vs Seed 9 TCU: TEAM_2 Winning Probability: 0.502
# Seed 7 Texas vs Seed 9 Texas A&M: TEAM_2 Winning Probability: 0.462
# Seed 7 Texas vs Seed 10 Colorado: TEAM_2 Winning Probability: 0.470
# Seed 7 Texas vs Seed 10 Nevada: TEAM_2 Winning Probability: 0.472
# Seed 7 Washington St. vs Seed 8 Florida Atlantic: TEAM_2 Winning Probability: 0.507
# Seed 7 Washington St. vs Seed 8 Mississippi St.: TEAM_2 Winning Probability: 0.549
# Seed 7 Washington St. vs Seed 8 Utah St.: TEAM_2 Winning Probability: 0.498
# Seed 7 Washington St. vs Seed 10 Boise St.: TEAM_2 Winning Probability: 0.526
# Seed 7 Washington St. vs Seed 10 Colorado St.: TEAM_2 Winning Probability: 0.517
# Seed 7 Washington St. vs Seed 10 Drake: TEAM_2 Winning Probability: 0.494
# Seed 7 Washington St. vs Seed 10 Virginia: TEAM_2 Winning Probability: 0.492
# Seed 7 Washington St. vs Seed 11 North Carolina St.: TEAM_2 Winning Probability: 0.455
# Seed 7 Washington St. vs Seed 11 Oregon: TEAM_2 Winning Probability: 0.508
# Seed 7 Washington St. vs Seed 12 Grand Canyon: TEAM_2 Winning Probability: 0.499
# Seed 7 Washington St. vs Seed 12 James Madison: TEAM_2 Winning Probability: 0.519
# Seed 7 Washington St. vs Seed 12 McNeese St.: TEAM_2 Winning Probability: 0.528
# Seed 8 Florida Atlantic vs Seed 10 Boise St.: TEAM_2 Winning Probability: 0.519
# Seed 8 Florida Atlantic vs Seed 10 Colorado St.: TEAM_2 Winning Probability: 0.510
# Seed 8 Florida Atlantic vs Seed 10 Drake: TEAM_2 Winning Probability: 0.487
# Seed 8 Florida Atlantic vs Seed 10 Virginia: TEAM_2 Winning Probability: 0.486
# Seed 8 Florida Atlantic vs Seed 11 Oregon: TEAM_2 Winning Probability: 0.502
# Seed 8 Florida Atlantic vs Seed 12 Grand Canyon: TEAM_2 Winning Probability: 0.493
# Seed 8 Florida Atlantic vs Seed 12 James Madison: TEAM_2 Winning Probability: 0.513
# Seed 8 Florida Atlantic vs Seed 12 McNeese St.: TEAM_2 Winning Probability: 0.522
# Seed 8 Mississippi St. vs Seed 9 Northwestern: TEAM_2 Winning Probability: 0.514
# Seed 8 Mississippi St. vs Seed 9 Texas A&M: TEAM_2 Winning Probability: 0.514
# Seed 8 Mississippi St. vs Seed 10 Boise St.: TEAM_2 Winning Probability: 0.476
# Seed 8 Mississippi St. vs Seed 10 Colorado: TEAM_2 Winning Probability: 0.522
# Seed 8 Mississippi St. vs Seed 10 Colorado St.: TEAM_2 Winning Probability: 0.467
# Seed 8 Mississippi St. vs Seed 10 Nevada: TEAM_2 Winning Probability: 0.524
# Seed 8 Mississippi St. vs Seed 11 Oregon: TEAM_2 Winning Probability: 0.459
# Seed 8 Mississippi St. vs Seed 12 James Madison: TEAM_2 Winning Probability: 0.470
# Seed 8 Mississippi St. vs Seed 12 McNeese St.: TEAM_2 Winning Probability: 0.479
# Seed 8 Nebraska vs Seed 9 Michigan St.: TEAM_2 Winning Probability: 0.536
# Seed 8 Nebraska vs Seed 9 Northwestern: TEAM_2 Winning Probability: 0.488
# Seed 8 Nebraska vs Seed 9 TCU: TEAM_2 Winning Probability: 0.527
# Seed 8 Nebraska vs Seed 9 Texas A&M: TEAM_2 Winning Probability: 0.488
# Seed 8 Nebraska vs Seed 10 Colorado: TEAM_2 Winning Probability: 0.496
# Seed 8 Nebraska vs Seed 10 Nevada: TEAM_2 Winning Probability: 0.498
# Seed 8 Nebraska vs Seed 12 McNeese St.: TEAM_2 Winning Probability: 0.452
# Seed 8 Utah St. vs Seed 10 Boise St.: TEAM_2 Winning Probability: 0.528
# Seed 8 Utah St. vs Seed 10 Colorado St.: TEAM_2 Winning Probability: 0.519
# Seed 8 Utah St. vs Seed 10 Drake: TEAM_2 Winning Probability: 0.496
# Seed 8 Utah St. vs Seed 10 Virginia: TEAM_2 Winning Probability: 0.494
# Seed 8 Utah St. vs Seed 11 North Carolina St.: TEAM_2 Winning Probability: 0.456
# Seed 8 Utah St. vs Seed 11 Oregon: TEAM_2 Winning Probability: 0.510
# Seed 8 Utah St. vs Seed 12 Grand Canyon: TEAM_2 Winning Probability: 0.501
# Seed 8 Utah St. vs Seed 12 James Madison: TEAM_2 Winning Probability: 0.521
# Seed 8 Utah St. vs Seed 12 McNeese St.: TEAM_2 Winning Probability: 0.530
# Seed 9 Michigan St. vs Seed 10 Colorado: TEAM_2 Winning Probability: 0.460
# Seed 9 Michigan St. vs Seed 10 Nevada: TEAM_2 Winning Probability: 0.462
# Seed 9 Northwestern vs Seed 10 Boise St.: TEAM_2 Winning Probability: 0.462
# Seed 9 Northwestern vs Seed 10 Colorado: TEAM_2 Winning Probability: 0.508
# Seed 9 Northwestern vs Seed 10 Colorado St.: TEAM_2 Winning Probability: 0.453
# Seed 9 Northwestern vs Seed 10 Nevada: TEAM_2 Winning Probability: 0.510
# Seed 9 Northwestern vs Seed 12 James Madison: TEAM_2 Winning Probability: 0.456
# Seed 9 Northwestern vs Seed 12 McNeese St.: TEAM_2 Winning Probability: 0.465
# Seed 9 TCU vs Seed 10 Colorado: TEAM_2 Winning Probability: 0.469
# Seed 9 TCU vs Seed 10 Nevada: TEAM_2 Winning Probability: 0.471
# Seed 9 Texas A&M vs Seed 10 Boise St.: TEAM_2 Winning Probability: 0.462
# Seed 9 Texas A&M vs Seed 10 Colorado: TEAM_2 Winning Probability: 0.508
# Seed 9 Texas A&M vs Seed 10 Colorado St.: TEAM_2 Winning Probability: 0.453
# Seed 9 Texas A&M vs Seed 10 Nevada: TEAM_2 Winning Probability: 0.510
# Seed 9 Texas A&M vs Seed 12 James Madison: TEAM_2 Winning Probability: 0.456
# Seed 9 Texas A&M vs Seed 12 McNeese St.: TEAM_2 Winning Probability: 0.464
# Seed 10 Boise St. vs Seed 11 Oregon: TEAM_2 Winning Probability: 0.483
# Seed 10 Boise St. vs Seed 12 Grand Canyon: TEAM_2 Winning Probability: 0.474
# Seed 10 Boise St. vs Seed 12 James Madison: TEAM_2 Winning Probability: 0.494
# Seed 10 Boise St. vs Seed 12 McNeese St.: TEAM_2 Winning Probability: 0.503
# Seed 10 Colorado vs Seed 12 McNeese St.: TEAM_2 Winning Probability: 0.456
# Seed 10 Colorado St. vs Seed 11 Oregon: TEAM_2 Winning Probability: 0.492
# Seed 10 Colorado St. vs Seed 12 Grand Canyon: TEAM_2 Winning Probability: 0.482
# Seed 10 Colorado St. vs Seed 12 James Madison: TEAM_2 Winning Probability: 0.503
# Seed 10 Colorado St. vs Seed 12 McNeese St.: TEAM_2 Winning Probability: 0.512
# Seed 10 Drake vs Seed 11 North Carolina St.: TEAM_2 Winning Probability: 0.461
# Seed 10 Drake vs Seed 11 Oregon: TEAM_2 Winning Probability: 0.515
# Seed 10 Drake vs Seed 12 Grand Canyon: TEAM_2 Winning Probability: 0.505
# Seed 10 Drake vs Seed 12 James Madison: TEAM_2 Winning Probability: 0.526
# Seed 10 Drake vs Seed 12 McNeese St.: TEAM_2 Winning Probability: 0.534
# Seed 10 Drake vs Seed 13 Samford: TEAM_2 Winning Probability: 0.454
# Seed 10 Nevada vs Seed 12 McNeese St.: TEAM_2 Winning Probability: 0.455
# Seed 10 Virginia vs Seed 11 North Carolina St.: TEAM_2 Winning Probability: 0.462
# Seed 10 Virginia vs Seed 11 Oregon: TEAM_2 Winning Probability: 0.516
# Seed 10 Virginia vs Seed 12 Grand Canyon: TEAM_2 Winning Probability: 0.507
# Seed 10 Virginia vs Seed 12 James Madison: TEAM_2 Winning Probability: 0.527
# Seed 10 Virginia vs Seed 12 McNeese St.: TEAM_2 Winning Probability: 0.536
# Seed 10 Virginia vs Seed 13 Samford: TEAM_2 Winning Probability: 0.456
# Seed 11 Duquesne vs Seed 13 College of Charleston: TEAM_2 Winning Probability: 0.483
# Seed 11 Duquesne vs Seed 13 Yale: TEAM_2 Winning Probability: 0.478
# Seed 11 North Carolina St. vs Seed 12 Grand Canyon: TEAM_2 Winning Probability: 0.545
# Seed 11 North Carolina St. vs Seed 13 Samford: TEAM_2 Winning Probability: 0.494
# Seed 11 Oregon vs Seed 12 Grand Canyon: TEAM_2 Winning Probability: 0.491
# Seed 11 Oregon vs Seed 12 James Madison: TEAM_2 Winning Probability: 0.511
# Seed 11 Oregon vs Seed 12 McNeese St.: TEAM_2 Winning Probability: 0.520
# Seed 12 UAB vs Seed 13 Vermont: TEAM_2 Winning Probability: 0.486
# Seed 14 Akron vs Seed 15 Western Kentucky: TEAM_2 Winning Probability: 0.464
# Seed 14 Colgate vs Seed 15 South Dakota St.: TEAM_2 Winning Probability: 0.503
# Seed 14 Colgate vs Seed 16 Longwood: TEAM_2 Winning Probability: 0.507
# Seed 14 Morehead St. vs Seed 15 Western Kentucky: TEAM_2 Winning Probability: 0.464
# Seed 14 Oakland vs Seed 15 Western Kentucky: TEAM_2 Winning Probability: 0.462
# Seed 15 South Dakota St. vs Seed 16 Longwood: TEAM_2 Winning Probability: 0.504

# %%
def print_matchups_for_team1_with_max_prob(df, team1, max_prob):
    """
    Searches for all matches involving team1 and prints out the matchups along with the probability
    of team1 winning each match, filtering to only include matches where team1's winning probability
    is at most the specified maximum probability.
    
    Parameters:
    - df: Pandas DataFrame containing the match data
    - team1: Name of Team 1
    - max_prob: Maximum winning probability (as a decimal) to include in the output
    """
    # Filter the dataframe for matches involving team1 either as TEAM_1 or TEAM_2
    matches = df[(df['TEAM_1'] == team1) | (df['TEAM_2'] == team1)]
    
    print(f"Matchups for {team1} with winning probabilities of {max_prob*100}% or lower:")
    
    # Track if any matches are found that meet the criteria
    matches_found = False

    for index, row in matches.iterrows():
        # Determine if team1 is TEAM_1 or TEAM_2 in the data
        if row['TEAM_1'] == team1:
            opponent = row['TEAM_2']
            prob = row['Team1W_Prob']
        else:
            opponent = row['TEAM_1']
            prob = 1 - row['Team1W_Prob']
        
        # Print only if the probability is at most the maximum threshold
        if prob <= max_prob:
            print(f"{team1} vs {opponent}: {prob:.3f}")
            matches_found = True
    
    if not matches_found:
        print(f"No matchups found for {team1} with winning probabilities of {max_prob*100}% or lower.")

# Example usage with a maximum probability threshold
print_matchups_for_team1_with_max_prob(df, "Purdue", 0.60)
# Out:
# Matchups for Purdue with winning probabilities of 60.0% or lower:
# Purdue vs Connecticut: 0.453
# Purdue vs Houston: 0.318
# Purdue vs Connecticut: 0.453
# Purdue vs Houston: 0.318
# Purdue vs Iowa St.: 0.566
# Purdue vs Iowa St.: 0.566
