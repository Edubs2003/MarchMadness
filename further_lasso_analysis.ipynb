# %%
import numpy as np
import pandas as pd

import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# # This Notebook makes a Dataframe of the testing dataset with the Lasso Model in order to better understand where the Lasso Model made the wrong prediction (to explore the match-up component of the model which doesn't take into account match-ups)

# %% [markdown]
# ## Lasso Model ##
#
# This is a Lasso model using 2008-2022 tournaments as training data and 2023 tournament as testing.

# %%
m = pd.read_csv('march.csv')
m
# Out:
#      YEAR               TEAM  CONF     G  WINS  LOSSES     W%  ADJOE  ADJDE  \
# 0    2008             Kansas   B12  33.0  30.0     3.0  0.909  121.0   85.6
# 1    2008     North Carolina   ACC  34.0  32.0     2.0  0.941  120.2   91.8
# 2    2008              Texas   B12  33.0  27.0     6.0  0.818  120.0   94.2
# 3    2008              Drake   MVC  30.0  26.0     4.0  0.867  118.0   96.3
# 4    2008             Oregon   P10  31.0  18.0    13.0  0.581  117.8  101.2
# ..    ...                ...   ...   ...   ...     ...    ...    ...    ...
# 955  2023                VCU   A10  34.0  27.0     7.0  0.794  104.2   93.1
# 956  2023        Montana St.  BSky  32.0  23.0     9.0  0.719  104.1   97.0
# 957  2023      UNC Asheville  BSth  32.0  25.0     7.0  0.781  101.2  102.4
# 958  2023  Northern Kentucky  Horz  32.0  20.0    12.0  0.625  101.1  101.1
# 959  2023             Howard  MEAC  31.0  19.0    12.0  0.613  100.9  105.7
#
#      EFG%  ...  2P%D   3P%  3P%D   3PR  3PRD  ADJ T.   WAB  SEED       FINISH  \
# 0    56.3  ...  40.9  39.9  34.0  29.2  38.1    69.5   9.9   1.0       CHAMPS
# 1    52.4  ...  47.0  37.8  33.2  22.2  34.8    75.1  11.9   1.0   Final Four
# 2    51.4  ...  43.6  37.7  33.2  34.3  38.9    64.8   8.4   2.0  Elite Eight
# 3    52.8  ...  49.2  36.6  33.8  45.5  39.3    64.2   5.2   5.0          R64
# 4    56.3  ...  50.1  40.1  33.6  39.0  35.3    67.9   0.8   9.0          R64
# ..    ...  ...   ...   ...   ...   ...   ...     ...   ...   ...          ...
# 955  52.2  ...  46.2  34.7  32.3  32.8  34.1    68.8   1.0  12.0          R64
# 956  50.9  ...  48.0  32.0  34.8  33.3  34.2    67.1  -2.7  14.0          R64
# 957  53.9  ...  49.1  38.8  30.5  37.2  34.0    69.1  -1.9  15.0          R64
# 958  49.8  ...  48.9  35.2  36.7  40.7  38.9    62.6  -6.7  16.0          R64
# 959  52.0  ...  50.8  37.2  33.6  36.1  37.1    69.7  -7.3  16.0          R64
#
#      T_WINS
# 0       6.0
# 1       4.0
# 2       3.0
# 3       0.0
# 4       0.0
# ..      ...
# 955     0.0
# 956     0.0
# 957     0.0
# 958     0.0
# 959     0.0
#
# [960 rows x 28 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error

# %%
m['Round of 64 Result'] = (m['T_WINS'] > 0).astype(int)
columns_to_drop = ['TEAM', 'CONF','FINISH','T_WINS', 'LOSSES','G','WINS']
final = m[m['YEAR'] == 2023]
m_num = m.drop(columns_to_drop, axis=1)

# %%
train_data = m_num[m_num['YEAR'] != 2023]
test_data = m_num[m_num['YEAR'] == 2023]

Y_train_m = train_data['Round of 64 Result']
Y_test_m = test_data['Round of 64 Result']

X_train_m = train_data.drop('Round of 64 Result', axis=1)
X_test_m = test_data.drop('Round of 64 Result', axis=1)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_m)
X_test_scaled = scaler.transform(X_test_m)

# %%
from sklearn.linear_model import LassoCV
from sklearn.metrics import accuracy_score

lasso_cv = LassoCV(cv=5)
lasso_cv.fit(X_train_scaled, Y_train_m)
optimal_alpha = lasso_cv.alpha_

thresholds = np.arange(0.1, 1.0, 0.001)
best_accuracy = 0.0
best_threshold = 0.0

for threshold in thresholds:
    y_pred_binary = (lasso_cv.predict(X_test_scaled) > threshold).astype(int)
    current_accuracy = accuracy_score(Y_test_m, y_pred_binary)

    if current_accuracy > best_accuracy:
        best_accuracy = current_accuracy
        best_threshold = threshold

print(f'Optimal Alpha: {optimal_alpha}')
print(f'Optimal Threshold: {best_threshold}')
print(f'Maximum Accuracy: {best_accuracy}')
# Out:
# Optimal Alpha: 0.016408803330353054
# Optimal Threshold: 0.4840000000000003
# Maximum Accuracy: 0.8125

# %%
predictions = lasso_cv.predict(X_test_scaled)
final['(Lasso) % Chance of Winning a Generic Round of 64 Game'] = predictions
# Out:
# /var/folders/0w/g3wjj_rs5c50q2c5fmh30m200000gn/T/ipykernel_45451/1350239319.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final['(Lasso) % Chance of Winning a Generic Round of 64 Game'] = predictions

# %% [markdown]
# ## Exploring

# %% [markdown]
# ### Lasso

# %%
final[
    (final['Round of 64 Result'] == 0) & 
    (final['(Lasso) % Chance of Winning a Generic Round of 64 Game'] > 0.484)
].sort_values(by='(Lasso) % Chance of Winning a Generic Round of 64 Game', ascending=False)
# Out:
#      YEAR           TEAM  CONF     G  WINS  LOSSES     W%  ADJOE  ADJDE  EFG%  \
# 903  2023         Purdue   B10  34.0  29.0     5.0  0.853  118.5   92.6  52.2
# 898  2023        Arizona   P12  34.0  28.0     6.0  0.824  119.7   95.4  56.8
# 936  2023       Virginia   ACC  32.0  25.0     7.0  0.781  110.4   93.5  51.3
# 945  2023       Iowa St.   B12  32.0  19.0    13.0  0.594  108.2   90.0  50.7
# 914  2023        Memphis  Amer  34.0  26.0     8.0  0.765  113.9   94.2  53.2
# 916  2023      Texas A&M   SEC  34.0  25.0     9.0  0.735  113.2   94.8  49.0
# 907  2023  West Virginia   B12  33.0  19.0    14.0  0.576  116.1   96.4  51.7
#
#      ...  3P%D   3PR  3PRD  ADJ T.  WAB  SEED  FINISH  T_WINS  \
# 903  ...  31.4  38.1  35.4    64.8  9.4   1.0     R64     0.0
# 898  ...  32.8  38.0  38.7    73.2  7.6   2.0     R64     0.0
# 936  ...  34.0  36.1  39.7    62.1  4.1   4.0     R64     0.0
# 945  ...  33.8  33.8  46.8    64.9  2.4   6.0     R64     0.0
# 914  ...  30.8  28.8  42.9    72.2  4.7   8.0     R64     0.0
# 916  ...  32.3  33.7  45.9    67.0  3.7   7.0     R64     0.0
# 907  ...  34.1  36.3  35.0    69.4  1.5   9.0     R64     0.0
#
#      Round of 64 Result  \
# 903                   0
# 898                   0
# 936                   0
# 945                   0
# 914                   0
# 916                   0
# 907                   0
#
#      (Lasso) % Chance of Winning a Generic Round of 64 Game
# 903                                           0.865989
# 898                                           0.794386
# 936                                           0.675727
# 945                                           0.643744
# 914                                           0.610148
# 916                                           0.606883
# 907                                           0.528026
#
# [7 rows x 30 columns]

# %%
final[
    (final['Round of 64 Result'] == 1) & 
    (final['(Lasso) % Chance of Winning a Generic Round of 64 Game'] < 0.484)
].sort_values(by='(Lasso) % Chance of Winning a Generic Round of 64 Game', ascending=False)
# Out:
#      YEAR                 TEAM CONF     G  WINS  LOSSES     W%  ADJOE  ADJDE  \
# 910  2023             Penn St.  B10  35.0  22.0    13.0  0.629  115.4   99.9
# 921  2023           Pittsburgh  ACC  33.0  22.0    11.0  0.667  112.5  101.5
# 924  2023               Furman   SC  31.0  24.0     7.0  0.774  111.9  104.1
# 948  2023            Princeton  Ivy  27.0  19.0     8.0  0.704  107.6  101.6
# 953  2023  Fairleigh Dickinson  NEC  32.0  17.0    15.0  0.531  104.6  117.0
#
#      EFG%  ...  3P%D   3PR  3PRD  ADJ T.   WAB  SEED         FINISH  T_WINS  \
# 910  55.5  ...  33.3  47.4  37.5    65.3   1.3  10.0            R32     1.0
# 921  53.2  ...  33.4  44.1  39.8    68.1  -0.3  11.0            R32     1.0
# 924  55.6  ...  33.1  46.4  35.2    69.1  -2.0  13.0            R32     1.0
# 948  52.5  ...  33.1  40.7  32.6    68.1  -3.2  15.0  Sweet Sixteen     2.0
# 953  51.5  ...  36.9  37.0  40.1    69.5 -12.2  16.0            R32     1.0
#
#      Round of 64 Result  \
# 910                   1
# 921                   1
# 924                   1
# 948                   1
# 953                   1
#
#      (Lasso) % Chance of Winning a Generic Round of 64 Game
# 910                                           0.406176
# 921                                           0.338697
# 924                                           0.248462
# 948                                           0.135508
# 953                                          -0.172848
#
# [5 rows x 30 columns]

# %%
final[
    (final['Round of 64 Result'] == 1) & 
    (final['(Lasso) % Chance of Winning a Generic Round of 64 Game'] > 0.484)
].sort_values(by='(Lasso) % Chance of Winning a Generic Round of 64 Game', ascending=False)
# Out:
#      YEAR              TEAM  CONF     G  WINS  LOSSES     W%  ADJOE  ADJDE  \
# 906  2023           Houston  Amer  34.0  31.0     3.0  0.912  117.1   88.0
# 917  2023              UCLA   P12  34.0  29.0     5.0  0.853  113.2   87.4
# 909  2023           Alabama   SEC  34.0  29.0     5.0  0.853  115.4   88.3
# 919  2023            Kansas   B12  34.0  27.0     7.0  0.794  112.9   91.5
# 913  2023             Texas   B12  34.0  26.0     8.0  0.765  114.6   91.6
# 899  2023         Marquette    BE  34.0  28.0     6.0  0.824  119.0   96.0
# 896  2023           Gonzaga   WCC  32.0  27.0     5.0  0.844  122.6   98.6
# 901  2023       Connecticut    BE  33.0  25.0     8.0  0.758  118.9   92.5
# 931  2023         Tennessee   SEC  33.0  23.0    10.0  0.697  111.1   86.2
# 897  2023            Baylor   B12  32.0  22.0    10.0  0.688  120.9   99.5
# 930  2023     San Diego St.   MWC  32.0  26.0     6.0  0.812  111.3   90.1
# 902  2023            Xavier    BE  34.0  25.0     9.0  0.735  118.6   98.4
# 926  2023      Saint Mary's   WCC  32.0  25.0     7.0  0.781  111.7   89.1
# 938  2023        Kansas St.   B12  32.0  23.0     9.0  0.719  110.3   93.1
# 925  2023              Duke   ACC  34.0  26.0     8.0  0.765  111.9   93.1
# 920  2023           Indiana   B10  33.0  22.0    11.0  0.667  112.5   95.8
# 929  51.1  ...  32.1  37.5  31.7    65.4   1.0   8.0            R32     1.0
# 932  49.6  ...  28.8  35.4  34.2    68.4   1.1   9.0            R32     1.0
#
#      Round of 64 Result  \
# 906                   1
# 917                   1
# 909                   1
# 919                   1
# 913                   1
# 899                   1
# 896                   1
# 901                   1
# 931                   1
# 897                   1
# 930                   1
# 902                   1
# 926                   1
# 938                   1
# 925                   1
# 920                   1
# 937                   1
# 905                   1
# 915                   1
# 904                   1
# 949                   1
# 922                   1
# 912                   1
# 935                   1
# 928                   1
# 929                   1
# 932                   1
#
#      (Lasso) % Chance of Winning a Generic Round of 64 Game
# 906                                           0.944496
# 917                                           0.914975
# 909                                           0.893305
# 919                                           0.876504
# 913                                           0.849596
# 899                                           0.848661
# 896                                           0.778578
# 901                                           0.753704
# 931                                           0.745816
# 897                                           0.724913
# 930                                           0.710042
# 902                                           0.693305
# 926                                           0.685963
# 938                                           0.684708
# 925                                           0.635291
# 920                                           0.613011
# 937                                           0.606095
# 905                                           0.594865
# 915                                           0.574820
# 904                                           0.574677
# 949                                           0.567372
# 922                                           0.552665
# 912                                           0.542318
# 935                                           0.529031
# 928                                           0.518922
# 929                                           0.505904
# 932                                           0.500551
#
# [27 rows x 30 columns]

# %%
final[
    (final['Round of 64 Result'] == 0) & 
    (final['(Lasso) % Chance of Winning a Generic Round of 64 Game'] < 0.484)
].sort_values(by='(Lasso) % Chance of Winning a Generic Round of 64 Game', ascending=True)
# Out:
#      YEAR                    TEAM  CONF     G  WINS  LOSSES     W%  ADJOE  \
# 959  2023                  Howard  MEAC  31.0  19.0    12.0  0.613  100.9
# 954  2023  Texas A&M Corpus Chris  Slnd  29.0  19.0    10.0  0.655  104.4
# 958  2023       Northern Kentucky  Horz  32.0  20.0    12.0  0.625  101.1
# 957  2023           UNC Asheville  BSth  32.0  25.0     7.0  0.781  101.2
# 939  2023            Grand Canyon   WAC  32.0  21.0    11.0  0.656  109.8
# 927  2023                 Colgate   Pat  33.0  25.0     8.0  0.758  111.7
# 946  2023                 Vermont    AE  32.0  22.0    10.0  0.688  107.9
# 943  2023        UC Santa Barbara    BW  32.0  25.0     7.0  0.781  108.7
# 952  2023            Kennesaw St.  ASun  31.0  23.0     8.0  0.742  105.0
# 956  2023             Montana St.  BSky  32.0  23.0     9.0  0.719  104.1
# 933  2023     Louisiana Lafayette    SB  30.0  23.0     7.0  0.767  110.8
# 942  2023                    Iona  MAAC  34.0  27.0     7.0  0.794  108.8
# 947  2023                   Drake   MVC  33.0  26.0     7.0  0.788  107.9
# 923  2023            Oral Roberts   Sum  30.0  26.0     4.0  0.867  111.9
# 950  2023                Kent St.   MAC  32.0  26.0     6.0  0.812  106.1
# 940  2023   College of Charleston   CAA  33.0  30.0     3.0  0.909  109.2
# 911  2023              Providence    BE  32.0  21.0    11.0  0.656  114.9
# 955  2023                     VCU   A10  34.0  27.0     7.0  0.794  104.2
# 951  2023             Arizona St.   P12  34.0  22.0    12.0  0.647  105.8
# 918  2023      North Carolina St.   ACC  33.0  23.0    10.0  0.697  113.0
# 934  2023                     USC   P12  32.0  22.0    10.0  0.688  110.8
# 941  2023                Illinois   B10  32.0  20.0    12.0  0.625  109.0
# 943                                           0.205381
# 952                                           0.217403
# 956                                           0.230537
# 933                                           0.276504
# 942                                           0.330631
# 947                                           0.339854
# 923                                           0.367425
# 950                                           0.381215
# 940                                           0.388498
# 911                                           0.400502
# 955                                           0.409371
# 951                                           0.423450
# 918                                           0.441759
# 934                                           0.447142
# 941                                           0.460953
# 944                                           0.465565
# 908                                           0.465659
# 900                                           0.483377
#
# [25 rows x 30 columns]

# %%
final.loc[(final['TEAM'] == 'Purdue') | (final['TEAM'] == 'Fairleigh Dickinson')]
### Double wrong
# Out:
#      YEAR                 TEAM CONF     G  WINS  LOSSES     W%  ADJOE  ADJDE  \
# 903  2023               Purdue  B10  34.0  29.0     5.0  0.853  118.5   92.6
# 953  2023  Fairleigh Dickinson  NEC  32.0  17.0    15.0  0.531  104.6  117.0
#
#      EFG%  ...  3P%D   3PR  3PRD  ADJ T.   WAB  SEED  FINISH  T_WINS  \
# 903  52.2  ...  31.4  38.1  35.4    64.8   9.4   1.0     R64     0.0
# 953  51.5  ...  36.9  37.0  40.1    69.5 -12.2  16.0     R32     1.0
#
#      Round of 64 Result  \
# 903                   0
# 953                   1
#
#      (Lasso) % Chance of Winning a Generic Round of 64 Game
# 903                                           0.865989
# 953                                          -0.172848
#
# [2 rows x 30 columns]

# %%
final.loc[(final['TEAM'] == 'Arizona') | (final['TEAM'] == 'Princeton')]
### Double wrong
# Out:
#      YEAR       TEAM CONF     G  WINS  LOSSES     W%  ADJOE  ADJDE  EFG%  ...  \
# 898  2023    Arizona  P12  34.0  28.0     6.0  0.824  119.7   95.4  56.8  ...
# 948  2023  Princeton  Ivy  27.0  19.0     8.0  0.704  107.6  101.6  52.5  ...
#
#      3P%D   3PR  3PRD  ADJ T.  WAB  SEED         FINISH  T_WINS  \
# 898  32.8  38.0  38.7    73.2  7.6   2.0            R64     0.0
# 948  33.1  40.7  32.6    68.1 -3.2  15.0  Sweet Sixteen     2.0
#
#      Round of 64 Result  \
# 898                   0
# 948                   1
#
#      (Lasso) % Chance of Winning a Generic Round of 64 Game
# 898                                           0.794386
# 948                                           0.135508
#
# [2 rows x 30 columns]

# %%
final.loc[(final['TEAM'] == 'Virginia') | (final['TEAM'] == 'Furman')]
### double wrong
# Out:
#      YEAR      TEAM CONF     G  WINS  LOSSES     W%  ADJOE  ADJDE  EFG%  ...  \
# 924  2023    Furman   SC  31.0  24.0     7.0  0.774  111.9  104.1  55.6  ...
# 936  2023  Virginia  ACC  32.0  25.0     7.0  0.781  110.4   93.5  51.3  ...
#
#      3P%D   3PR  3PRD  ADJ T.  WAB  SEED  FINISH  T_WINS  Round of 64 Result  \
# 924  33.1  46.4  35.2    69.1 -2.0  13.0     R32     1.0                   1
# 936  34.0  36.1  39.7    62.1  4.1   4.0     R64     0.0                   0
#
#      (Lasso) % Chance of Winning a Generic Round of 64 Game
# 924                                           0.248462
# 936                                           0.675727
#
# [2 rows x 30 columns]

# %%
final.loc[(final['TEAM'] == 'Iowa St.') | (final['TEAM'] == 'Pittsburgh')]
### double wrong
# Out:
#      YEAR        TEAM CONF     G  WINS  LOSSES     W%  ADJOE  ADJDE  EFG%  \
# 921  2023  Pittsburgh  ACC  33.0  22.0    11.0  0.667  112.5  101.5  53.2
# 945  2023    Iowa St.  B12  32.0  19.0    13.0  0.594  108.2   90.0  50.7
#
#      ...  3P%D   3PR  3PRD  ADJ T.  WAB  SEED  FINISH  T_WINS  \
# 921  ...  33.4  44.1  39.8    68.1 -0.3  11.0     R32     1.0
# 945  ...  33.8  33.8  46.8    64.9  2.4   6.0     R64     0.0
#
#      Round of 64 Result  \
# 921                   1
# 945                   0
#
#      (Lasso) % Chance of Winning a Generic Round of 64 Game
# 921                                           0.338697
# 945                                           0.643744
#
# [2 rows x 30 columns]

# %%
final.loc[(final['TEAM'] == 'Memphis') | (final['TEAM'] == 'Florida Atlantic')]
### one wrong
# Out:
#      YEAR              TEAM  CONF     G  WINS  LOSSES     W%  ADJOE  ADJDE  \
# 914  2023           Memphis  Amer  34.0  26.0     8.0  0.765  113.9   94.2
# 922  2023  Florida Atlantic  CUSA  32.0  29.0     3.0  0.906  112.2   94.8
#
#      EFG%  ...  3P%D   3PR  3PRD  ADJ T.  WAB  SEED      FINISH  T_WINS  \
# 914  53.2  ...  30.8  28.8  42.9    72.2  4.7   8.0         R64     0.0
# 922  55.0  ...  32.0  43.8  34.2    68.9  4.7   9.0  Final Four     4.0
#
#      Round of 64 Result  \
# 914                   0
# 922                   1
#
#      (Lasso) % Chance of Winning a Generic Round of 64 Game
# 914                                           0.610148
# 922                                           0.552665
#
# [2 rows x 30 columns]

# %%
final.loc[(final['TEAM'] == 'Texas A&M') | (final['TEAM'] == 'Penn St.')]
### double wrong
# Out:
#      YEAR       TEAM CONF     G  WINS  LOSSES     W%  ADJOE  ADJDE  EFG%  ...  \
# 910  2023   Penn St.  B10  35.0  22.0    13.0  0.629  115.4   99.9  55.5  ...
# 916  2023  Texas A&M  SEC  34.0  25.0     9.0  0.735  113.2   94.8  49.0  ...
#
#      3P%D   3PR  3PRD  ADJ T.  WAB  SEED  FINISH  T_WINS  Round of 64 Result  \
# 910  33.3  47.4  37.5    65.3  1.3  10.0     R32     1.0                   1
# 916  32.3  33.7  45.9    67.0  3.7   7.0     R64     0.0                   0
#
#      (Lasso) % Chance of Winning a Generic Round of 64 Game
# 910                                           0.406176
# 916                                           0.606883
#
# [2 rows x 30 columns]

# %%
final.loc[(final['TEAM'] == 'Iowa') | (final['TEAM'] == 'Auburn')]
### one wrong
# Out:
#      YEAR    TEAM CONF     G  WINS  LOSSES     W%  ADJOE  ADJDE  EFG%  ...  \
# 900  2023    Iowa  B10  32.0  19.0    13.0  0.594  118.9  102.7  51.9  ...
# 932  2023  Auburn  SEC  32.0  20.0    12.0  0.625  110.9   93.2  49.6  ...
#
#      3P%D   3PR  3PRD  ADJ T.  WAB  SEED  FINISH  T_WINS  Round of 64 Result  \
# 900  36.6  37.4  32.2    70.4  0.3   8.0     R64     0.0                   0
# 932  28.8  35.4  34.2    68.4  1.1   9.0     R32     1.0                   1
#
#      (Lasso) % Chance of Winning a Generic Round of 64 Game
# 900                                           0.483377
# 932                                           0.500551
#
# [2 rows x 30 columns]

# %%
len(final[final['(Lasso) % Chance of Winning a Generic Round of 64 Game'] > 0.484])/64
# Out:
# 0.53125

# %%
len(final[final['(Lasso) % Chance of Winning a Generic Round of 64 Game'] < 0.484])/64
# Out:
# 0.46875
